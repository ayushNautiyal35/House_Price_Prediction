# %% [markdown]
# # 1. Problem Statement: To predict the price of the houses.

# %% [markdown]
# # 2. Collection of data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
#for memory space
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 3.9 MB

# %% [markdown]
# After step we got to know that:
# 1. The data contains 1460 rows and 81 columns.
# 2. The data contains Null values.
# 3. The data takes  3.9 MB space.
# 4. The data contains mixture of int64 and object data types.

# %% [markdown]
# # 3. Data Cleaning

# %%
#for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
#to check for null values
for col in data.columns:
    if data[col].isnull().sum()!=0:
        print(f"{col} -> {data[col].isnull().sum()}")
# Out:
# LotFrontage -> 259
# Alley -> 1369
# MasVnrType -> 872
# MasVnrArea -> 8
# BsmtQual -> 37
# BsmtCond -> 37
# BsmtExposure -> 38
# BsmtFinType1 -> 37
# BsmtFinType2 -> 38
# Electrical -> 1
# FireplaceQu -> 690
# GarageType -> 81
# GarageYrBlt -> 81
# GarageFinish -> 81
# GarageQual -> 81
# GarageCond -> 81
# PoolQC -> 1453
# Fence -> 1179
# MiscFeature -> 1406

# %%
data['LotFrontage'].dtypes
# Out:
# dtype('float64')

# %%
data['LotFrontage'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
data['LotFrontage'].value_counts()
# Out:
# LotFrontage
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
#         ...
# 137.0      1
# 141.0      1
# 38.0       1
# 140.0      1
# 46.0       1
# Name: count, Length: 110, dtype: int64

# %%
#choosing 60.0 for missing values at LotFrontage
data['LotFrontage']=data['LotFrontage'].fillna(60.0)

# %%
data['Alley'].dtypes
# Out:
# dtype('O')

# %%
data['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
data['Alley']=data['Alley'].fillna('Grvl')

# %%
data['MasVnrType'].dtypes
# Out:
# dtype('O')

# %%
data['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
data['MasVnrType']=data['MasVnrType'].fillna('BrkFace')

# %%
data['MasVnrArea'].dtypes
# Out:
# dtype('float64')

# %%
data['MasVnrArea'].describe()
# Out:
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
data['MasVnrArea'].value_counts()
# Out:
# MasVnrArea
# 0.0      861
# 180.0      8
# 72.0       8
# 108.0      8
# 120.0      7
#         ...
# 562.0      1
# 89.0       1
# 921.0      1
# 762.0      1
# 119.0      1
# Name: count, Length: 327, dtype: int64

# %%
#going with median for  MasVnrArea
data['MasVnrArea']=data['MasVnrArea'].fillna(data['MasVnrArea'].median())

# %%
data['BsmtQual'].dtypes
# Out:
# dtype('O')

# %%
data['BsmtQual'].value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
data['BsmtQual']=data['BsmtQual'].fillna('TA')

# %%
data['BsmtCond'].dtypes
# Out:
# dtype('O')

# %%
data['BsmtCond'].value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
data['BsmtCond']=data['BsmtCond'].fillna('TA')

# %%
data['BsmtExposure'].dtypes
# Out:
# dtype('O')

# %%
data['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
data['BsmtExposure']=data['BsmtExposure'].fillna('No')

# %%
data['BsmtFinType1'].dtypes
# Out:
# dtype('O')

# %%
data['BsmtFinType1'].value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
data['BsmtFinType1']=data['BsmtFinType1'].fillna('Unf')

# %%
data['BsmtFinType2'].dtypes
# Out:
# dtype('O')

# %%
data['BsmtFinType2'].value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
data['BsmtFinType2']=data['BsmtFinType2'].fillna('Unf')

# %%
data['Electrical'].dtypes
# Out:
# dtype('O')

# %%
data['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
data['Electrical']=data['Electrical'].fillna('SBrkr')

# %%
data['FireplaceQu'].dtypes
# Out:
# dtype('O')

# %%
data['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
data['FireplaceQu']=data['FireplaceQu'].fillna('Gd')

# %%
data['GarageType'].dtypes
# Out:
# dtype('O')

# %%
data['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
data['GarageType']=data['GarageType'].fillna('Attchd')

# %%
data['GarageYrBlt'].dtypes
# Out:
# dtype('float64')

# %%
data['GarageYrBlt'].describe()
# Out:
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
data['GarageYrBlt'].value_counts()
# Out:
# GarageYrBlt
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1927.0     1
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1933.0     1
# Name: count, Length: 97, dtype: int64

# %%
data['GarageYrBlt']=data['GarageYrBlt'].fillna(data['GarageYrBlt'].median())

# %%
data['GarageFinish'].dtypes
# Out:
# dtype('O')

# %%
data['GarageFinish'].value_counts()
# Out:
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64

# %%
data['GarageFinish']=data['GarageFinish'].fillna('Unf')

# %%
data['GarageQual'].dtypes
# Out:
# dtype('O')

# %%
data['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
data['GarageQual']=data['GarageQual'].fillna('TA')

# %%
data['GarageCond'].dtypes
# Out:
# dtype('O')

# %%
data['GarageCond'].value_counts()
# Out:
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
data['GarageCond']=data['GarageCond'].fillna('TA')

# %%
data.drop(columns=['PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          1460 non-null   object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1460 non-null   object
#  26  MasVnrArea     1460 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1460 non-null   object
#  31  BsmtCond       1460 non-null   object
#  32  BsmtExposure   1460 non-null   object
#  33  BsmtFinType1   1460 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1460 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1460 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    1460 non-null   object
#  58  GarageType     1460 non-null   object
#  59  GarageYrBlt    1460 non-null   float64
#  60  GarageFinish   1460 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1460 non-null   object
#  64  GarageCond     1460 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  MiscVal        1460 non-null   int64
#  73  MoSold         1460 non-null   int64
#  74  YrSold         1460 non-null   int64
#  75  SaleType       1460 non-null   object
#  76  SaleCondition  1460 non-null   object
#  77  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(40)
# memory usage: 889.8+ KB

# %%
#now converting data type of the object type
object_dtypes=[]
for col in data.columns:
    if data[col].dtypes=='object':
        object_dtypes.append(col)
object_dtypes
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
from sklearn.preprocessing import  LabelEncoder
lb=LabelEncoder()
for i in object_dtypes:
    data[i]=lb.fit_transform(data[i])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 78 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int32
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int32
#  6   Alley          1460 non-null   int32
#  7   LotShape       1460 non-null   int32
#  8   LandContour    1460 non-null   int32
#  9   Utilities      1460 non-null   int32
#  10  LotConfig      1460 non-null   int32
#  11  LandSlope      1460 non-null   int32
#  12  Neighborhood   1460 non-null   int32
#  13  Condition1     1460 non-null   int32
#  14  Condition2     1460 non-null   int32
#  15  BldgType       1460 non-null   int32
#  16  HouseStyle     1460 non-null   int32
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   int32
#  22  RoofMatl       1460 non-null   int32
#  23  Exterior1st    1460 non-null   int32
#  24  Exterior2nd    1460 non-null   int32
#  25  MasVnrType     1460 non-null   int32
#  26  MasVnrArea     1460 non-null   float64
#  27  ExterQual      1460 non-null   int32
#  28  ExterCond      1460 non-null   int32
#  29  Foundation     1460 non-null   int32
#  30  BsmtQual       1460 non-null   int32
#  31  BsmtCond       1460 non-null   int32
#  32  BsmtExposure   1460 non-null   int32
#  33  BsmtFinType1   1460 non-null   int32
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1460 non-null   int32
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   int32
#  40  HeatingQC      1460 non-null   int32
#  41  CentralAir     1460 non-null   int32
#  42  Electrical     1460 non-null   int32
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   int32
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   int32
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    1460 non-null   int32
#  58  GarageType     1460 non-null   int32
#  59  GarageYrBlt    1460 non-null   float64
#  60  GarageFinish   1460 non-null   int32
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1460 non-null   int32
#  64  GarageCond     1460 non-null   int32
#  65  PavedDrive     1460 non-null   int32
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  MiscVal        1460 non-null   int64
#  73  MoSold         1460 non-null   int64
#  74  YrSold         1460 non-null   int64
#  75  SaleType       1460 non-null   int32
#  76  SaleCondition  1460 non-null   int32
#  77  SalePrice      1460 non-null   int64
# dtypes: float64(3), int32(40), int64(35)
# memory usage: 661.7 KB

# %% [markdown]
# In 3 step we  have done:
# 1. Remove all Null values.
# 2. Remove the columns which have majorly null values.
# 3. Convert object data type to int.

# %% [markdown]
# #  4. Data analysis and Feature engineering

# %%
#id not needed
data=data.drop('Id',axis=1)

# %%
#now finding correlation between the attributes
co=data.corr()

# %%
co['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
#                   ...
# HeatingQC      -0.400178
# GarageFinish   -0.537242
# KitchenQual    -0.589189
# BsmtQual       -0.618025
# ExterQual      -0.636884
# Name: SalePrice, Length: 77, dtype: float64

# %%
include=[]
c=co['SalePrice']
for i in data.columns:
    if c[i]>0.4:
        print(f"{i} -> {c[i]}")
        include.append(i)
    elif -1*c[i]>0.4:
        print(f"{i} -> {c[i]}")
        include.append(i)
# Out:
# OverallQual -> 0.7909816005838053
# YearBuilt -> 0.5228973328794967
# YearRemodAdd -> 0.5071009671113866
# MasVnrArea -> 0.4726144990045735
# ExterQual -> -0.6368836943991116
# BsmtQual -> -0.6180253538653229
# TotalBsmtSF -> 0.6135805515591943
# HeatingQC -> -0.400177543162901
# 1stFlrSF -> 0.6058521846919153
# GrLivArea -> 0.7086244776126515
# FullBath -> 0.5606637627484453
# KitchenQual -> -0.589188778299423
# TotRmsAbvGrd -> 0.5337231555820284
# Fireplaces -> 0.46692883675152763
# GarageYrBlt -> 0.4667536523633407
# GarageFinish -> -0.5372421226773465
# GarageCars -> 0.6404091972583519
# GarageArea -> 0.6234314389183622
# SalePrice -> 1.0

# %%
data=data[include]
data
# Out:
#       OverallQual  YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  BsmtQual  \
# 0               7       2003          2003       196.0          2         2
# 1               6       1976          1976         0.0          3         2
# 2               7       2001          2002       162.0          2         2
# 3               7       1915          1970         0.0          3         3
# 4               8       2000          2000       350.0          2         2
# ...           ...        ...           ...         ...        ...       ...
# 1455            6       1999          2000         0.0          3         2
# 1456            6       1978          1988       119.0          3         2
# 1457            7       1941          2006         0.0          0         3
# 1458            5       1950          1996         0.0          3         3
# 1459            5       1965          1965         0.0          2         3
#
#       TotalBsmtSF  HeatingQC  1stFlrSF  GrLivArea  FullBath  KitchenQual  \
# 0             856          0       856       1710         2            2
# 1            1262          0      1262       1262         2            3
# 2             920          0       920       1786         2            2
# 3             756          2       961       1717         1            2
# 4            1145          0      1145       2198         2            2
# ...           ...        ...       ...        ...       ...          ...
# 1455          953          0       953       1647         2            3
# 1456         1542          4      2073       2073         2            3
# 1457         1152          0      1188       2340         2            2
# 1458         1078          2      1078       1078         1            2
# 1459         1256          2      1256       1256         1            3
#
#       TotRmsAbvGrd  Fireplaces  GarageYrBlt  GarageFinish  GarageCars  \
# 0                8           0       2003.0             1           2
# 1                6           1       1976.0             1           2
# 2                6           1       2001.0             1           2
# 3                7           1       1998.0             2           3
# 4                9           1       2000.0             1           3
# ...            ...         ...          ...           ...         ...
# 1455             7           1       1999.0             1           2
# 1456             7           2       1978.0             2           2
# 1457             9           2       1941.0             1           1
# 1458             5           0       1950.0             2           1
# 1459             6           0       1965.0             0           1
#
#       GarageArea  SalePrice
# 0            548     208500
# 1            460     181500
# 2            608     223500
# 3            642     140000
# 4            836     250000
# ...          ...        ...
# 1455         460     175000
# 1456         500     210000
# 1457         252     266500
# 1458         240     142125
# 1459         276     147500
#
# [1460 rows x 19 columns]

# %%
target=data['SalePrice']

# %%
df=data.drop('SalePrice',axis=1)

# %%
import seaborn as sns
fig, axes = plt.subplots(6, 3, figsize=(18, 36), sharey=True)
k=0
for i in range(6):
    for j in range(3):
        sns.regplot(x=df.columns[k],y='SalePrice',data=data,ax=axes[i][j])
        plt.plot()
        k+=1

# %%
#to detect outliers
fig, axes = plt.subplots(6, 3, figsize=(18, 36), sharey=True)
k=0
for i in range(6):
    for j in range(3):
        sns.boxplot(y=df.columns[k],data=data,ax=axes[i][j])
        plt.plot()
        k+=1

# %%
data.columns
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual',
#        'BsmtQual', 'TotalBsmtSF', 'HeatingQC', '1stFlrSF', 'GrLivArea',
#        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
# to resolve outlier problem using iqr
import numpy as np
arr=['MasVnrArea','TotalBsmtSF','1stFlrSF','GrLivArea','GarageArea']
for i in arr:
    q1=data[i].quantile(0.25)
    q3=data[i].quantile(0.75)
    iqr=q3-q1
    maximum=q3+1.5*iqr
    minimum=q1-1.5*iqr
    
    for j in range(0,len(data[i])):
        if data[i][j]>maximum or data[i][j]<minimum:
            data[i][j]=data[i].median()

# %%
#breaking into train and test data
df=data.drop('SalePrice',axis=1)
target=data['SalePrice']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df, target, test_size=0.3, random_state=42)

# %%
y_train.shape
# Out:
# (1022,)

# %% [markdown]
# in the 4th step we:
# 1. Analyse th data and found only 19 columns are relevant.
# 2. Detect outliers and resolve it.
# 3. Break into test and train data.

# %% [markdown]
# # 5. Model Selection

# %%
#this is regression prolem so try for the model which gives best result in regression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error
def check(model):
    y_pred=model.predict(x_test)
    
    mae = mean_absolute_error(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    msle = mean_squared_log_error(y_test, y_pred)

    print(f'MAE: {mae}')
    print(f'MSE: {mse}')
    print(f'RMSE: {rmse}')
    print(f'R-squared: {r2}')
    print(f'MSLE: {msle}')

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression().fit(x_train,y_train)
check(lr)
# Out:
# MAE: 24278.341093602274
# MSE: 1414765672.4915197
# RMSE: 37613.37092699244
# R-squared: 0.7972561388597506
# MSLE: 0.03722532942817844

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(3).fit(x_train,y_train)
check(knn)
# Out:
# MAE: 26493.36681887367
# MSE: 2028797181.6575344
# RMSE: 45042.171147243054
# R-squared: 0.7092619773878701
# MSLE: 0.043652882731616084

# %%
from sklearn.svm import SVR
svm=SVR().fit(x_train,y_train)
check(svm)
# Out:
# MAE: 57026.56018554389
# MSE: 7199520617.235673
# RMSE: 84849.98890533618
# R-squared: -0.0317317112498301
# MSLE: 0.1695227277035599

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor().fit(x_train,y_train)
check(dt)
# Out:
# MAE: 29078.52511415525
# MSE: 2413527911.73516
# RMSE: 49127.6695125584
# R-squared: 0.654127904493751
# MSLE: 0.0519988611590238

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor().fit(x_train,y_train)
check(rf)
# Out:
# MAE: 19171.588215372907
# MSE: 872173832.4317175
# RMSE: 29532.589328261034
# R-squared: 0.8750125947986236
# MSLE: 0.024933367555474137

# %%
from sklearn.ensemble import BaggingRegressor
br=BaggingRegressor().fit(x_train,y_train)
check(br)
# Out:
# MAE: 20412.842503805172
# MSE: 952927881.2139884
# RMSE: 30869.52998045141
# R-squared: 0.8634400863817403
# MSLE: 0.02796407575334279

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor().fit(x_train,y_train)
check(ada)
# Out:
# MAE: 26131.15382036907
# MSE: 1257719564.7633803
# RMSE: 35464.34215889786
# R-squared: 0.8197617275073585
# MSLE: 0.04587476943507562

# %%
from sklearn.ensemble import ExtraTreesRegressor
ex=ExtraTreesRegressor().fit(x_train,y_train)
check(ex)
# Out:
# MAE: 20542.197773972603
# MSE: 1045026517.3926886
# RMSE: 32326.8698978526
# R-squared: 0.8502418349202547
# MSLE: 0.02764656504944803

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor().fit(x_train,y_train)
check(gb)
# Out:
# MAE: 19905.48861643557
# MSE: 857056938.6942568
# RMSE: 29275.53481482886
# R-squared: 0.877178930513698
# MSLE: 0.024594539612980693

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
hsb=HistGradientBoostingRegressor().fit(x_train,y_train)
check(hsb)
# Out:
# MAE: 19820.931240274906
# MSE: 949533928.389412
# RMSE: 30814.50840739492
# R-squared: 0.8639264588698221
# MSLE: 0.024781670797666647

# %%
#from comparing all ML model it is found to be gradientboostingregressor to be best 
#now to select best hyperparameters
parameters={
    'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
    'criterion':['friedman_mse', 'squared_error'],
    'max_features':['sqrt', 'log2'],
    'learning_rate':[0.1,0.2,0.3,0.4]}

# %% [markdown]
# from sklearn.model_selection import GridSearchCV
# gb=GradientBoostingRegressor()
#
# cv=GridSearchCV(gb,parameters,cv=3,verbose=2)
# cv.fit(x_train,y_train)

# %% [markdown]
# cv.best_estimator_

# %% [markdown]
# cv.best_params_

# %% [markdown]
# cv.best_score_

# %%
model=GradientBoostingRegressor(criterion= 'friedman_mse',learning_rate=0.1,loss='squared_error',max_features='log2').fit(x_train,y_train)

# %%
model.predict(x_test)
# Out:
# array([136885.36125467, 351331.86708553, 124627.19722756, 175675.62009319,
#        317306.19712349,  83641.55203559, 195728.33217736, 152472.70430603,
#         80406.27053222, 112004.46762172, 157705.70376967, 121059.44300494,
#        130606.25790072, 206725.47425578, 189586.17328954, 122242.07078189,
#        200303.46472935, 132441.94876106, 123290.57100565, 206725.47425578,
#        203106.43690578, 229411.95875092, 182128.36666216, 130105.81874075,
#        208909.33914501, 178393.52690648, 183721.90971745, 105614.0379599 ,
#        189345.26782063, 214258.20204653, 121607.53973734, 253753.13289107,
#        275062.07596977, 101724.27138363, 254404.31574597, 147143.6548966 ,
#        139110.53736765, 205427.41050015, 334178.5924497 , 108462.36624248,
#        144276.72099097, 250366.39612974, 112538.82819331, 385467.03245692,
#        126493.90954112, 139084.17139625, 112566.37393571, 114019.84023437,
#        485373.72626377, 121248.90843033, 106575.4821836 , 210463.97989777,
#        128261.49308197, 250121.46406903, 148599.94676602, 222243.39692718,
#        196881.26319315, 203854.84486372, 149484.58096   , 126271.38422888,
#         68059.87823832, 146801.99271588, 322041.19649555, 274304.33907283,
#        303869.38228596, 210651.55734243, 103451.09405756, 338585.13397699,
#        120299.32237303, 160619.16699616, 140688.73381883, 128018.34120727,
#        101751.81712603, 102993.28133769, 490163.88734119, 171142.45386254,
#        304781.5173888 , 291678.05355359, 133204.95125748, 108476.21325649,
#        106999.48498829, 105056.60017414, 135681.26398438, 107202.16227989,
#        147604.8106876 , 128311.96702675, 263558.25654145, 188290.19956873,
#        148599.94676602, 181466.49335965, 157305.99632539, 149023.92891029,
#        115716.69498512, 242062.69253579, 125679.62316505, 175285.37299799,
#        177038.64840089, 170680.98811878, 208906.77285485, 250384.20902945,
#        179766.92751328, 196567.17137328, 219477.34111389, 138534.91656665,
#        167914.31446059, 189487.40109163, 150751.4925937 , 240504.66725053,
#        143980.81181259, 192915.32731223,  76714.81873616, 116498.72821271,
#        129269.50250415, 128939.87879678, 202934.22312354, 133154.25551433,
#        108785.16645716, 120576.31443189, 155739.90400084, 250575.46130366,
#        150962.83125202, 149992.90238517, 186196.36927545, 164642.60438446,
#        177570.64138783, 112388.66247883, 240288.89247697,  98247.72064089,
#        147378.18195698, 182616.13550531, 184556.33744675, 348189.63858742,
#        199469.24602784, 122816.1005803 ,  71013.15525588, 355954.56567224,
#        362922.24060101, 115540.42190128, 230919.01896373, 600901.1093525 ,
#        322470.49554164, 119760.2031966 , 189339.95252622, 169839.37741403,
#        138740.9128411 , 132389.1019147 , 205632.85112903, 204433.33413965,
#        122105.79966022,  66942.90400751, 112602.27250267, 142478.62154152,
#        264426.5383311 , 156009.57772407, 101284.17071342, 121404.26982552,
#        145767.11227195, 153399.83610817,  77485.02233033, 134864.22668702,
#        233134.33908301, 153333.37516042, 268768.90792089, 166338.2406703 ,
#        106136.42244976, 130005.64743762, 215108.08075244, 371335.27537578,
#        464306.08856179, 216196.58801279, 290430.7426013 ,  88512.98129097,
#        113698.40454295, 170169.27968267, 295000.65997331, 163660.38557262,
#        144914.50008094, 212847.75453231, 124928.79992191, 165482.09422764,
#        169454.44425149, 115290.28247525, 128984.69701978, 156421.75513573,
#        242988.68090731, 142237.46893044, 293658.13412066, 227272.37709174,
#        187457.78534674,  84192.83163509, 126260.7284311 , 112256.13841777,
#        131817.0567648 , 142867.2347496 , 177392.24774328, 180191.77517486,
#        211695.04458959,  88628.9446251 , 221625.76854918, 110271.06879803,
#        215821.11518109, 168980.33424784, 111823.89132561, 297952.09954339,
#        187562.37446182, 128244.37490434, 256636.56206979, 139376.73476446,
#        175598.19770676, 120631.77765817, 250232.51682436, 150460.21141308,
#         90681.4556331 , 158220.31635286, 189088.22915292, 249479.61478961,
#        238411.18443694, 144432.74904387, 125236.96329523, 152366.16225631,
#        134947.85228849, 216627.74351397, 192975.06826045, 100980.74079559,
#        270582.80702521, 137422.17705083, 117991.22840781, 105449.95854042,
#        155488.69437134, 101986.93687384, 109607.95436521, 184165.42422817,
#        118555.86936328, 122151.06815826, 241048.23845525, 116906.68858433,
#        186505.26929202, 148283.40616311, 223219.41981992, 142847.01433466,
#        113111.15155479, 243228.06459926, 205933.85343073, 416987.85842857,
#        186375.81224067, 114430.48958971, 141198.45490884, 168361.79198048,
#        145881.92305103, 101656.67335089, 181625.76994531, 187466.81892166,
#        125187.40265563,  97355.60259977, 132480.24745263, 156114.60968589,
#        113854.31116205, 110424.53007225, 185548.21121394, 267073.44685994,
#        303259.08134849, 164950.77164409, 114735.26851133, 211484.48417765,
#        298680.06487637, 236808.86868753, 181654.75449146, 143879.69685326,
#        128172.86337492, 168508.08884736, 372567.64046293, 226612.6933686 ,
#        225790.35717363,  99616.28522123, 121569.49300639, 136199.39849934,
#        173479.61167976, 321330.36615695, 232816.28405873, 141323.49869513,
#        201362.97826611,  93915.55804897, 187850.08314739, 108029.4858581 ,
#        296575.64295133, 191491.68762195, 199058.4153956 , 123530.06603328,
#        229356.01494834, 179180.50476191, 134706.59267687, 113148.06281339,
#        136298.86599323, 186974.52630091,  79507.41720413, 151492.36716176,
#        147903.71701225, 126307.44265099, 184556.89947079, 101950.3530734 ,
#        186437.13355571, 228111.02545309, 118230.41955112, 147348.89652343,
#        186513.18134042, 163668.09558438, 154996.41144741, 233788.26148918,
#        202399.28378009, 137900.18841305, 148504.04093882, 193987.11891162,
#         87357.71981104, 175562.1140289 , 144310.88564354, 186893.35547423,
#        184202.89986171, 165169.0056001 , 297575.0580613 , 102006.32517588,
#        233232.00417716, 133664.43287013, 124274.08639095,  86529.17161075,
#        175894.58670541, 184046.58400249, 132664.5699524 , 188636.50680707,
#        184065.25130405, 100617.51128938, 168637.97057783, 139142.60715207,
#        136045.80973999, 205243.80678399, 164324.47694004, 129355.15222021,
#        135809.29294607, 106251.14700001,  86217.96148858, 204649.23922629,
#        188839.33968816, 140288.31618774, 127262.34766455, 191289.70045688,
#        238421.94030411, 379441.83280085, 310301.71204165, 126489.35234567,
#        202684.32827833, 124790.77158731, 312039.56213014, 333388.68524378,
#        259950.01669557, 167187.96450469, 287089.2929741 , 133867.01967369,
#        114407.34667239,  88537.85510098, 200415.12147453, 305083.46386723,
#        191499.09754595, 134071.50502194, 256297.58037625, 208899.62753426,
#        126385.04213411, 205814.46240143, 156926.58272223, 104101.42837063,
#        138097.61425669, 144920.06888699, 114601.63482176, 189586.17328954,
#        135425.65470125, 224171.44779946, 158361.03344324, 126546.63463328,
#        203861.03750894, 211281.11207206,  97285.5920433 , 216218.86128013,
#        149650.16948424, 183437.72832338, 186135.92772828, 152457.26877409,
#        120616.30953134, 233466.64507255, 127276.99288628, 128629.63075939,
#        304235.09373976, 171003.28951214, 127093.33276322, 167044.46711936,
#        154198.40225517, 348889.69595576, 148710.1552629 , 455791.29536186,
#        126466.47837138, 166669.34900005, 178216.0541129 , 122582.627968  ,
#        172746.36782189, 297143.62920316, 102722.10762608, 147501.87998912,
#        143420.52861836, 105895.68718336, 208806.04549381, 155865.1524025 ,
#        217245.97007135, 197418.90389489, 210311.63506138, 206725.47425578,
#         65320.47764213, 310692.72482193, 140127.78545559, 345314.99913146,
#        121445.56241267, 457494.94431986, 265991.55696177, 120365.27409425,
#        224921.56253016, 263517.05977169, 197418.90389489, 163915.50630354,
#        329706.29618384, 129355.08223123, 211133.99400673, 166990.51537645,
#        180624.10720261, 229176.67334219, 122912.99255632, 160607.64094082,
#        189486.53544496, 132916.92783728, 114115.36333588, 201087.84632828,
#        125955.77236987, 516402.70612509])

# %% [markdown]
# In step 5 we get:
# 1. different models are tested.
# 2. Best comes to be Gradientboostnregressor with accuracy of 87.65%
# 3. Best hyperparameters are selected.

# %% [markdown]
# # 6. Saving result and model

# %% [markdown]
# import joblib
# joblib.dump(model, 'model.joblib')

# %%
# now prediction for sample test case provided
test=pd.read_csv('test.csv')

# %%
include.pop()
# Out:
# 'SalePrice'

# %%
len(include)
# Out:
# 18

# %%
df=test[include]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OverallQual   1459 non-null   int64
#  1   YearBuilt     1459 non-null   int64
#  2   YearRemodAdd  1459 non-null   int64
#  3   MasVnrArea    1444 non-null   float64
#  4   ExterQual     1459 non-null   object
#  5   BsmtQual      1415 non-null   object
#  6   TotalBsmtSF   1458 non-null   float64
#  7   HeatingQC     1459 non-null   object
#  8   1stFlrSF      1459 non-null   int64
#  9   GrLivArea     1459 non-null   int64
#  10  FullBath      1459 non-null   int64
#  11  KitchenQual   1458 non-null   object
#  12  TotRmsAbvGrd  1459 non-null   int64
#  13  Fireplaces    1459 non-null   int64
#  14  GarageYrBlt   1381 non-null   float64
#  15  GarageFinish  1381 non-null   object
#  16  GarageCars    1458 non-null   float64
#  17  GarageArea    1458 non-null   float64
# dtypes: float64(5), int64(8), object(5)
# memory usage: 205.3+ KB

# %%
df.isnull().sum()
# Out:
# OverallQual      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea      15
# ExterQual        0
# BsmtQual        44
# TotalBsmtSF      1
# HeatingQC        0
# 1stFlrSF         0
# GrLivArea        0
# FullBath         0
# KitchenQual      1
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt     78
# GarageFinish    78
# GarageCars       1
# GarageArea       1
# dtype: int64

# %%
import warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df['GarageCars']=df['GarageCars'].fillna(2.0)

# %%
df['GarageArea']=df['GarageArea'].fillna(df['GarageArea'].median())

# %%
df['KitchenQual'].value_counts()
# Out:
# KitchenQual
# TA    757
# Gd    565
# Ex    105
# Fa     31
# Name: count, dtype: int64

# %%
df['KitchenQual']=df['KitchenQual'].fillna("TA")

# %%
df['MasVnrArea']=df['MasVnrArea'].fillna(df['MasVnrArea'].median())

# %%
df['BsmtQual']=df['BsmtQual'].fillna('TA')

# %%
df['TotalBsmtSF']=df['TotalBsmtSF'].fillna(df['TotalBsmtSF'].median())

# %%
df['GarageYrBlt']=df['GarageYrBlt'].fillna(df['GarageYrBlt'].median())

# %%
df['GarageFinish']=df['GarageFinish'].fillna('Unf')

# %%
object_dtypes=[]
for col in df.columns:
    if df[col].dtypes=='object':
        object_dtypes.append(col)
object_dtypes
from sklearn.preprocessing import  LabelEncoder
lb=LabelEncoder()
for i in object_dtypes:
    df[i]=lb.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OverallQual   1459 non-null   int64
#  1   YearBuilt     1459 non-null   int64
#  2   YearRemodAdd  1459 non-null   int64
#  3   MasVnrArea    1459 non-null   float64
#  4   ExterQual     1459 non-null   int32
#  5   BsmtQual      1459 non-null   int32
#  6   TotalBsmtSF   1459 non-null   float64
#  7   HeatingQC     1459 non-null   int32
#  8   1stFlrSF      1459 non-null   int64
#  9   GrLivArea     1459 non-null   int64
#  10  FullBath      1459 non-null   int64
#  11  KitchenQual   1459 non-null   int32
#  12  TotRmsAbvGrd  1459 non-null   int64
#  13  Fireplaces    1459 non-null   int64
#  14  GarageYrBlt   1459 non-null   float64
#  15  GarageFinish  1459 non-null   int32
#  16  GarageCars    1459 non-null   float64
#  17  GarageArea    1459 non-null   float64
# dtypes: float64(5), int32(5), int64(8)
# memory usage: 176.8 KB

# %%
test['SalePrice']=model.predict(df)

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN        Gar2   12500
# 2         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition      SalePrice
# 0      6   2010        WD         Normal  115763.568556
# 1      6   2010        WD         Normal  135189.697391
# 2      3   2010        WD         Normal  183142.953759
# 3      6   2010        WD         Normal  192911.649208
# 4      1   2010        WD         Normal  222458.521175
#
# [5 rows x 81 columns]

# %%
res={'Id':test['Id'],'SalePrice':test['SalePrice']}

# %%
df=pd.DataFrame(res)

# %%
df.to_csv('result.csv')
